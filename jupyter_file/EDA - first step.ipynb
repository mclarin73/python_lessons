# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Посмотреть и понимать данные

# %%
df = pd.read_csv('/Users/alksandr/Desktop/StudentsPerformance.csv')

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
np.round(df.describe(),2)
# Out:
#        math score  reading score  writing score
# count     1000.00        1000.00        1000.00
# mean        66.09          69.17          68.05
# std         15.16          14.60          15.20
# min          0.00          17.00          10.00
# 25%         57.00          59.00          57.75
# 50%         66.00          70.00          69.00
# 75%         77.00          79.00          79.00
# max        100.00         100.00         100.00

# %%
df.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 982    male        group B            some high school      standard
# 130    male        group D             master's degree      standard
# 184    male        group C            some high school  free/reduced
# 862    male        group D           bachelor's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 982               completed          79             85             86
# 130                    none          89             84             82
# 184               completed          45             52             49
# 862               completed          39             42             38
# 165               completed          96            100            100

# %%
df.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
for typ, col in zip(df.dtypes, df.columns):
    print(f'{col} {typ} {df[col].isnull().sum()}')
# Out:
# gender object 0
# race/ethnicity object 0
# parental level of education object 0
# lunch object 0
# test preparation course object 0
# math score int64 0
# reading score int64 0
# writing score int64 0

# %%
for i in df.columns:
    print(f'Columns: {i} have type {df[i].dtype} and value with null {df[i].isnull().sum()}\n')
# Out:
# Columns: gender have type object and value with null 0
#
# Columns: race/ethnicity have type object and value with null 0
#
# Columns: parental level of education have type object and value with null 0
#
# Columns: lunch have type object and value with null 0
#
# Columns: test preparation course have type object and value with null 0
#
# Columns: math score have type int64 and value with null 0
#
# Columns: reading score have type int64 and value with null 0
#
# Columns: writing score have type int64 and value with null 0

# %%
# Не правильно!
for i in df.columns:
    print(f'Columns: {i} have type {type(i)} and value with null {df[i].isnull().sum()}\n')
# Out:
# female
# Columns: gender have type <class 'str'> and value with null 0
#
# Columns: race/ethnicity have type <class 'str'> and value with null 0
#
# Columns: parental level of education have type <class 'str'> and value with null 0
#
# Columns: lunch have type <class 'str'> and value with null 0
#
# Columns: test preparation course have type <class 'str'> and value with null 0
#
# Columns: math score have type <class 'str'> and value with null 0
#
# Columns: reading score have type <class 'str'> and value with null 0
#
# Columns: writing score have type <class 'str'> and value with null 0

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
df.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
student = df.drop(['race/ethnicity', 'parental level of education'], axis = 1)

# %%
student.head()
# Out:
#    gender         lunch test preparation course  math score  reading score  \
# 0  female      standard                    none          72             72
# 1  female      standard               completed          69             90
# 2  female      standard                    none          90             95
# 3    male  free/reduced                    none          47             57
# 4    male      standard                    none          76             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
# матрица корреляции

# %%
corelation = student.corr()
corelation
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(corelation, xticklabels= corelation.columns, 
           yticklabels= corelation.columns, annot = True);

# %%
sns.pairplot(student);

# %%
 #sns.relplot(x = 'math score', y = 'reading score', hue = 'lunch', date = student);

# %%
student[student['writing score'] < 60]
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 3      male  free/reduced                    none          47             57
# 7      male  free/reduced                    none          40             43
# 9    female  free/reduced                    none          38             60
# 10     male      standard                    none          58             54
# 11     male      standard                    none          40             52
# ..      ...           ...                     ...         ...            ...
# 980  female  free/reduced                    none           8             24
# 985    male      standard                    none          57             51
# 986  female      standard                    none          40             59
# 988  female  free/reduced                    none          44             45
# 996    male  free/reduced                    none          62             55
#
#      writing score
# 3               44
# ...

# %%
student.head(3)
# Out:
#    gender     lunch test preparation course  math score  reading score  \
# 0  female  standard                    none          72             72
# 1  female  standard               completed          69             90
# 2  female  standard                    none          90             95
#
#    writing score
# 0             74
# 1             88
# 2             93

# %%
df.head()
# Out:
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
df[(df['writing score'] >= 60) & (df['reading score'] >= 60) & (df['math score'] >= 60)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st1 = student[(student['writing score'] >= 60) & (student['reading score'] >= 60) & (student['math score'] >= 60)]
st1
# Out:
#      gender         lunch test preparation course  math score  reading score  \
# 0    female      standard                    none          72             72
# 1    female      standard               completed          69             90
# 2    female      standard                    none          90             95
# 4      male      standard                    none          76             78
# 5    female      standard                    none          71             83
# ..      ...           ...                     ...         ...            ...
# 993  female  free/reduced                    none          62             72
# 994    male      standard                    none          63             63
# 995  female      standard               completed          88             99
# 998  female      standard               completed          68             78
# 999  female  free/reduced                    none          77             86
#
#      writing score
# 0               74
# ...

# %%
sns.pairplot(st1);

# %%
'''
df = df[['writing score']]
df_counted_1 = df[df['writing score'] >= 60].count()
df_counted_1

writing_rate = (df_counted_1 * 100) / df['writing score'].count()
writing_rate
'''
# Out:
# writing score    71.9
# dtype: float64

# %%
sns.displot(student['writing score'], bins = 20);

# %%
sns.catplot(x = 'math score', kind = 'box', data = student);

# %%
sns.countplot(data = student);

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
titanic.tail(7)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 884         0       3    male  25.0      0      0   7.050        S   Third
# 885         0       3  female  39.0      0      5  29.125        Q   Third
# 886         0       2    male  27.0      0      0  13.000        S  Second
# 887         1       1  female  19.0      0      0  30.000        S   First
# 888         0       3  female   NaN      1      2  23.450        S   Third
# 889         1       1    male  26.0      0      0  30.000        C   First
# 890         0       3    male  32.0      0      0   7.750        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# ...

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 596         1       2  female   NaN      0      0   33.0000        S  Second
# 234         0       2    male  24.0      0      0   10.5000        S  Second
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 233         1       3  female   5.0      4      2   31.3875        S   Third
# 527         0       1    male   NaN      0      0  221.7792        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 596  woman       False  NaN  Southampton   yes   True
# 234    man        True  NaN  Southampton    no   True
# 341  woman       False    C  Southampton   yes  False
# 233  child       False  NaN  Southampton   yes  False
# 527    man        True    C  Southampton    no   True

# %%
titanic.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'survived', data = titanic);

# %%
sns.countplot(x = 'survived', hue = 'sex', data = titanic);

# %%
sns.countplot(x = 'survived', hue = 'pclass', data= titanic, palette = 'rainbow');

# %%
sns.displot(titanic['age'].dropna(), kde = True, bins = 20);

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].hist(bins = 10, alpha = .6);

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.sibsp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
sns.countplot(x = 'sibsp', data = titanic);

# %%
titanic['fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
titanic['fare'].hist(figsize = (9,5), bins = 10);

# %%
sns.boxplot(x = 'pclass', y = 'age', data = titanic);

# %%
# cleaning data

# %%
cols = ['survived', 'sex', 'pclass', 'sibsp', 'parch', 'embarked']
nr_rows = 2
nr_cols = 3

# %%
fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3))

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        
        i = r*nr_cols+c       
        ax = axs[r][c]
        sns.countplot(titanic[cols[i]], hue=titanic["survived"], ax=ax)
        ax.set_title(cols[i], fontsize=14, fontweight='bold')
        ax.legend(title="survived", loc='upper center') 
        
plt.tight_layout()
# Out:
# /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.barplot(x='pclass', y='survived', data= titanic)
plt.ylabel("Survival Rate")
plt.title("Survival as function of Pclass")
plt.show()

# %%
sns.barplot(x='sex', y='survived', hue='pclass', data= titanic)
plt.ylabel("Survival Rate")
plt.title("Survival as function of Pclass and Sex")
plt.show()

# %%
sns.barplot(x='embarked', y='survived', data= titanic)
plt.ylabel("Survival Rate")
plt.title("Survival as function of Embarked Port")
plt.show()

# %%
sns.barplot(x='embarked', y='survived', hue='pclass', data = titanic)
plt.ylabel("Survival Rate")
plt.title("Survival as function of Embarked Port")
plt.show()

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sex_surv = titanic.groupby(['sex'])['survived'].mean().to_frame()
sex_surv
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.groupby(['survived', 'alone','class','adult_male']).count()
# Out:
#                                   pclass  sex  age  sibsp  parch  fare  \
# survived alone class  adult_male
# 0        False First  False            2    2    2      2      2     2
#                       True            27   27   27     27     27    27
#                Second False            3    3    3      3      3     3
#                       True            26   26   26     26     26    26
#                Third  False           67   67   56     67     67    67
#                       True            50   50   36     50     50    50
#          True  First  False            1    1    1      1      1     1
#                       True            50   50   34     50     50    50
#                Second False            3    3    3      3      3     3
#                       True            65   65   58     65     65    65
#                Third  False           24   24   18     24     24    24
#                       True           231  231  160    231    231   231
# ...

# %%
sex_surv = titanic.groupby(['pclass'])['survived'].mean().to_frame()
sex_surv
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import tree

from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
titanic.embark_town.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
titanic = titanic.fillna({"embarked": 'C'})

# %%
#help_to_gen = ['Southampton', 'Cherbourg', 'Queenstown']
#titanic = titanic.fillna({"embark_town": 'Southampton'})

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         1  Third    man
# 1         1       1    1  38.0      1      0  71.2833         2  First  woman
# 2         1       3    1  26.0      0      0   7.9250         1  Third  woman
# 3         1       1    1  35.0      1      0  53.1000         1  First  woman
# 4         0       3    1  35.0      0      0   8.0500         1  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
def sex_change(value):
    return 0 if value == 'male' else 1

# %%
titanic['sex'] = titanic['sex'].apply(sex_change)
titanic.sex.unique()
# Out:
# array([0, 1])

# %%
def change_embadred(value):
    help_dict = {"S": 1, "C": 2, "Q": 3}
    return help_dict[value.upper()]

# %%
titanic['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
titanic['embarked'] = titanic['embarked'].apply(change_embadred)
titanic.embarked.unique()
# Out:
# array([1, 2, 3])

# %%
titanic['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
titanic['embark_town'] = titanic['embark_town'].fillna(method='ffill')
titanic['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
titanic['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic['age'].isnull().sum()
# Out:
# 177

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500         1  Third    man
# 1         1       1    1  38.0      1      0  71.2833         2  First  woman
# 2         1       3    1  26.0      0      0   7.9250         1  Third  woman
# 3         1       1    1  35.0      1      0  53.1000         1  First  woman
# 4         0       3    0  35.0      0      0   8.0500         1  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].mean())

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.deck.unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic = titanic.drop(labels=['deck'],axis=1)

# %%
titanic.shape
# Out:
# (891, 14)

# %%
int(False), int(True)
# Out:
# (0, 1)

# %%
def change_embadred(value):
    help_dict = {"S": 1, "C": 2, "Q": 3}
    return help_dict[value.upper()]

titanic['embarked'] = titanic['embarked'].apply(change_embadred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [329], in <cell line: 5>()
#       2     help_dict = {"S": 1, "C": 2, "Q": 3}
#       3     return help_dict[value.upper()]
# ----> 5 titanic['embarked'] = titanic['embarked'].apply(change_embadred)
#
# File /usr/local/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500         1  Third    man
# 1         1       1    1  38.0      1      0  71.2833         2  First  woman
# 2         1       3    1  26.0      0      0   7.9250         1  Third  woman
# 3         1       1    1  35.0      1      0  53.1000         1  First  woman
# 4         0       3    0  35.0      0      0   8.0500         1  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
