# %% [markdown]
# ## Work with dataset. House sell

# %%
# import module
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/Users/alksandr/Downloads/data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
# ...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.size
# Out:
# 82800

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df['waterfront'].dtype
# Out:
# dtype('int64')

# %%
pd.Series([1000, 2000, 3000], name='price', dtype = float)
# Out:
# 0    1000.0
# 1    2000.0
# 2    3000.0
# Name: price, dtype: float64

# %%
df['city'].astype(str)
# Out:
# 0       Shoreline
# 1         Seattle
# 2            Kent
# 3        Bellevue
# 4         Redmond
#           ...
# 4595      Seattle
# 4596     Bellevue
# 4597       Renton
# 4598      Seattle
# 4599    Covington
# Name: city, Length: 4600, dtype: object

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df['bedrooms'].value_counts()
# Out:
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
df['bedrooms'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.sort_values('price')[::-1]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# ...                   ...         ...       ...        ...          ...
# 4411  2014-05-22 00:00:00         0.0       5.0       2.25         2000
# 4408  2014-05-21 00:00:00         0.0       5.0       2.25         2880
# 4481  2014-06-11 00:00:00         0.0       5.0       2.75         3240
# 4542  2014-06-25 00:00:00         0.0       5.0       3.50         2640
# 4472  2014-06-09 00:00:00         0.0       4.0       3.75         4060
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df[(df['bedrooms'] > 5) & (df['bathrooms'] > 1.5)].describe()
# Out:
#               price   bedrooms  bathrooms   sqft_living       sqft_lot  \
# count  7.500000e+01  75.000000  75.000000     75.000000      75.000000
# mean   8.898031e+05   6.280000   3.313333   3619.040000   26111.786667
# std    6.510410e+05   0.582631   1.125633   1672.550451   56592.155717
# min    0.000000e+00   6.000000   1.750000   1670.000000    2370.000000
# 25%    4.750000e+05   6.000000   2.500000   2765.000000    5716.000000
# 50%    6.700000e+05   6.000000   3.000000   3150.000000    8400.000000
# 75%    1.130000e+06   6.000000   4.125000   4025.000000   15641.000000
# max    3.200000e+06   9.000000   8.000000  13540.000000  307752.000000
#
#           floors  waterfront       view  condition   sqft_above  \
# count  75.000000   75.000000  75.000000  75.000000    75.000000
# mean    1.673333    0.013333   0.920000   3.613333  2707.973333
# std     0.617828    0.115470   1.430932   0.769228  1311.961045
# min     1.000000    0.000000   0.000000   2.000000   900.000000
# ...

# %%
df[(df['bedrooms'] > 5) & (df['bathrooms'] > 1.5)].head(3)
# Out:
#                     date      price  bedrooms  bathrooms  sqft_living  \
# 92   2014-05-05 00:00:00   823000.0       6.0       1.75         2920
# 122  2014-05-05 00:00:00  2280000.0       7.0       8.00        13540
# 170  2014-05-06 00:00:00   475000.0       6.0       3.00         3470
#
#      sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 92       5000     2.5           0     0          4        2780            140
# 122    307752     3.0           0     4          3        9410           4130
# 170    117612     1.5           0     0          3        3470              0
#
#      yr_built  yr_renovated             street     city  statezip country
# 92       1908             0       125 29th Ave  Seattle  WA 98122     USA
# 122      1999             0   26408 NE 70th St  Redmond  WA 98053     USA
# 170      1924          2011  19007 80th Ave NE  Kenmore  WA 98028     USA

# %%
df[(df['price'] < 500000) & (df['yr_built'] > 2001)].head(5)
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 31  2014-05-02 00:00:00  499950.0       4.0       2.50         2860      3345
# 58  2014-05-02 00:00:00  385000.0       3.0       3.25         1320      1327
# 59  2014-05-02 00:00:00  295000.0       2.0       2.50         1630      1368
# 61  2014-05-02 00:00:00  459990.0       3.0       2.50         2680      5539
# 63  2014-05-02 00:00:00  300000.0       3.0       2.50         2540      5050
#
#     floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 31     2.0           0     0          3        2190            670      2004
# 58     2.0           0     0          3        1040            280      2008
# 59     2.0           0     0          3        1280            350      2009
# 61     2.0           0     0          3        2680              0      2013
# 63     2.0           0     0          3        2540              0      2006
#
# ...

# %%
df[(df['yr_built'] > 2001) & (df['price']<210000)].sort_values('price')
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 4374  2014-05-09 00:00:00       0.0       2.0       2.50         2200
# 4382  2014-05-12 00:00:00       0.0       5.0       4.50         4630
# 4383  2014-05-13 00:00:00       0.0       5.0       4.00         4430
# 4385  2014-05-13 00:00:00       0.0       4.0       4.50         5030
# 4389  2014-05-15 00:00:00       0.0       4.0       3.50         4210
# 4472  2014-06-09 00:00:00       0.0       4.0       3.75         4060
# 4481  2014-06-11 00:00:00       0.0       5.0       2.75         3240
# 4523  2014-06-23 00:00:00       0.0       3.0       4.50         5230
# 4528  2014-06-24 00:00:00       0.0       4.0       5.00         4550
# 4462  2014-06-05 00:00:00  132250.0       4.0       2.25         2192
# 3160  2014-06-23 00:00:00  160797.0       3.0       1.50         1270
# 1018  2014-05-20 00:00:00  194000.0       1.0       1.00          820
#
# ...

# %%
# %%time
df[(df['yr_built'] > 2001) & (df['price'] > 200000) & (df['bedrooms'] > 2) & (df['price'] < 500000)]
# Out:
# CPU times: user 1.43 ms, sys: 181 µs, total: 1.61 ms
# Wall time: 1.49 ms
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 31    2014-05-02 00:00:00  499950.000000       4.0       2.50         2860
# 58    2014-05-02 00:00:00  385000.000000       3.0       3.25         1320
# 61    2014-05-02 00:00:00  459990.000000       3.0       2.50         2680
# 63    2014-05-02 00:00:00  300000.000000       3.0       2.50         2540
# 98    2014-05-05 00:00:00  406100.000000       3.0       2.25         1410
# ...                   ...            ...       ...        ...          ...
# 4561  2014-06-30 00:00:00  433111.111111       3.0       2.25         1370
# 4569  2014-07-02 00:00:00  268971.875000       4.0       2.50         1954
# 4586  2014-07-07 00:00:00  430277.777778       3.0       2.25         1620
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# ...

# %%
df[df['bedrooms'] >= 8]
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 241       6988     2.5           0     0          3        2450
# 1500      6480     2.0           0     3          5        3140
# 3911      6695     1.0           0     0          3        1470
#
#       sqft_basement  yr_built  yr_renovated               street       city  \
# 241            1380      1938          2003  8809 Densmore Ave N    Seattle
# 1500           1300      1959             0      1210 22nd Ave E    Seattle
# 3911           1320      1977          2004  17512 Corliss Ave N  Shoreline
#
#       statezip country
# 241   WA 98103     USA
# 1500  WA 98112     USA
# 3911  WA 98133     USA

# %%
df['bedrooms'].value_counts()
# Out:
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
#df['price'].apply(lambda x: int(x))
# Out:
# 0        313000
# 1       2384000
# 2        342000
# 3        420000
# 4        550000
#          ...
# 4595     308166
# 4596     534333
# 4597     416904
# 4598     203400
# 4599     220600
# Name: price, Length: 4600, dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', 'Lake Forest Park', 'Sammamish',
#        'Auburn', 'Des Moines', 'Bothell', 'Federal Way', 'Kirkland',
#        'Issaquah', 'Woodinville', 'Normandy Park', 'Fall City', 'Renton',
#        'Carnation', 'Snoqualmie', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Newcastle', 'Mercer Island',
#        'Black Diamond', 'Ravensdale', 'Clyde Hill', 'Algona', 'Skykomish',
#        'Tukwila', 'Vashon', 'Yarrow Point', 'SeaTac', 'Medina',
#        'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village',
#        'Preston', 'Milton'], dtype=object)

# %%
df[df['bedrooms'].isin([3,4]) & (df['price'] < 300000) & (df['city'].isin(['Redmond', 'SeaTac']))]
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 583   2014-05-13 00:00:00  225000.0       4.0       1.50         1950
# 992   2014-05-20 00:00:00  210000.0       4.0       1.75         2180
# 1184  2014-05-22 00:00:00  180000.0       4.0       1.50         1740
# 1502  2014-05-28 00:00:00  242000.0       3.0       1.75         1310
# 1528  2014-05-29 00:00:00  267500.0       3.0       1.75         1590
# 1541  2014-05-29 00:00:00  145000.0       3.0       1.00         1010
# 1993  2014-06-05 00:00:00  237000.0       3.0       1.00         1130
# 2144  2014-06-09 00:00:00  234999.0       3.0       1.00         1330
# 2455  2014-06-13 00:00:00  235000.0       3.0       1.75         1900
# 2655  2014-06-17 00:00:00  170000.0       4.0       1.00         1920
# 2743  2014-06-18 00:00:00  253779.0       4.0       2.00         2030
# 2862  2014-06-19 00:00:00  287000.0       3.0       2.00         1300
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
pd.to_datetime('29/08/2021 14:00:00') - pd.to_datetime('29/07/1998 13:00:00')
# Out:
# Timedelta('8432 days 01:00:00')

# %%
df.groupby('bedrooms').agg(np.average)
# Out:
# /var/folders/jg/4z3wkn2j4qg_d9rhsgxmg9340000gn/T/ipykernel_1900/2657842226.py:1: FutureWarning: ['date', 'street', 'city', 'statezip', 'country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('bedrooms').agg(np.average)
#                  price  bathrooms  sqft_living      sqft_lot    floors  \
# bedrooms
# 0.0       1.195324e+06   0.000000  3937.000000  16386.000000  2.750000
# 1.0       2.740763e+05   1.072368   822.105263   9425.710526  1.144737
# 2.0       3.916219e+05   1.401943  1247.268551  12137.515901  1.303004
# 3.0       4.886130e+05   1.996924  1829.022638  13249.980315  1.472195
# 4.0       6.351194e+05   2.472894  2608.437622  16609.540823  1.627694
# 5.0       7.701860e+05   2.859065  3140.390935  18985.892351  1.576487
# 6.0       8.173628e+05   2.979508  3321.606557  24394.918033  1.631148
# ...

# %%
df[(df['bedrooms'].isin([4,9])) & (df['price'] < 500000) & (df['price'] > 300000)& (df['city'].isin(['Woodinville','Kent']))].head()
# Out:
#                     date     price  bedrooms  bathrooms  sqft_living  \
# 31   2014-05-02 00:00:00  499950.0       4.0       2.50         2860
# 209  2014-05-06 00:00:00  483500.0       4.0       2.50         2740
# 292  2014-05-07 00:00:00  480500.0       4.0       2.50         2180
# 336  2014-05-08 00:00:00  325900.0       4.0       2.50         2320
# 348  2014-05-08 00:00:00  350000.0       4.0       1.75         2250
#
#      sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 31       3345     2.0           0     0          3        2190            670
# 209     45732     2.0           0     0          3        2740              0
# 292     11200     1.0           0     0          4        2180              0
# 336      6270     2.0           0     0          3        2320              0
# 348     13515     1.0           0     0          4        2150            100
#
#      yr_built  yr_renovated              street         city  statezip country
# ...

# %%
df[df['city'].isin(['Redmond', 'SeaTac']) & (df['bedrooms'].isin([2,4])) & (df['price'] > 300000)].describe()
# Out:
#               price    bedrooms  bathrooms  sqft_living       sqft_lot  \
# count  1.250000e+02  125.000000  125.00000   125.000000     125.000000
# mean   6.974342e+05    3.568000    2.45600  2627.904000   26745.904000
# std    1.960865e+05    0.826341    0.53794   879.809367   44806.210782
# min    3.150000e+05    2.000000    1.00000   790.000000    1369.000000
# 25%    5.650000e+05    4.000000    2.25000  2090.000000    6327.000000
# 50%    6.846800e+05    4.000000    2.50000  2490.000000    9571.000000
# 75%    8.020000e+05    4.000000    2.50000  3110.000000   33206.000000
# max    1.360000e+06    4.000000    4.50000  5430.000000  265716.000000
#
#            floors  waterfront        view   condition   sqft_above  \
# count  125.000000       125.0  125.000000  125.000000   125.000000
# mean     1.592000         0.0    0.040000    3.176000  2450.784000
# std      0.525111         0.0    0.321288    0.441113   949.964996
# ...

# %%
df[df['city'].isin(['Seattle','Redmond']) & (df['bedrooms'].isin([4,5,6])) & (df['price'] > 300000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 1 to 4572
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           565 non-null    object
#  1   price          565 non-null    float64
#  2   bedrooms       565 non-null    float64
#  3   bathrooms      565 non-null    float64
#  4   sqft_living    565 non-null    int64
#  5   sqft_lot       565 non-null    int64
#  6   floors         565 non-null    float64
#  7   waterfront     565 non-null    int64
#  8   view           565 non-null    int64
#  9   condition      565 non-null    int64
#  10  sqft_above     565 non-null    int64
#  11  sqft_basement  565 non-null    int64
#  12  yr_built       565 non-null    int64
#  13  yr_renovated   565 non-null    int64
#  14  street         565 non-null    object
#  15  city           565 non-null    object
#  16  statezip       565 non-null    object
# ...

# %%
#df[df['city'].isin(['Bellevue', 'Issaquah', 'Auburn']) & (df['price'] > 250000)].head()
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 3   2014-05-02 00:00:00  420000.0       3.0       2.25         2000      8030
# 16  2014-05-02 00:00:00  419000.0       3.0       1.50         1570      6700
# 17  2014-05-02 00:00:00  367500.0       4.0       3.00         3110      7231
# 21  2014-05-02 00:00:00  435000.0       4.0       1.00         1450      8800
# 28  2014-05-02 00:00:00  675000.0       5.0       2.50         2820     67518
#
#     floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 3      1.0           0     0          4        1000           1000      1963
# 16     1.0           0     0          4        1570              0      1956
# 17     2.0           0     0          3        3110              0      1997
# 21     1.0           0     0          4        1450              0      1954
# 28     2.0           0     0          3        2820              0      1979
#
# ...

# %%
df.groupby('bedrooms').agg( {'price': ['mean', 'median'], 'bathrooms' : ['max', 'min']})
# Out:
#                  price            bathrooms
#                   mean     median       max   min
# bedrooms
# 0.0       1.195324e+06  1195324.0      0.00  0.00
# 1.0       2.740763e+05   262500.0      2.25  0.75
# 2.0       3.916219e+05   369500.0      3.25  0.75
# 3.0       4.886130e+05   424750.0      4.50  0.75
# 4.0       6.351194e+05   568000.0      5.50  0.75
# 5.0       7.701860e+05   580000.0      6.75  1.00
# 6.0       8.173628e+05   665000.0      5.25  1.00
# 7.0       1.049429e+06   711500.0      8.00  2.50
# 8.0       1.155000e+06  1155000.0      3.50  2.75
# 9.0       5.999990e+05   599999.0      4.50  4.50

# %%
#df.rename(columns = {'price': 'full_price'}, inplace = False)

# %%
#df.drop(df['waterfront'], axis = 0, inplace = False)

# %%
#df[df['price'] > 250000].nlargest(10, 'price')
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 3729  2014-07-01 00:00:00   3800000.0       5.0       5.50         7050
# 1637  2014-05-30 00:00:00   3710000.0       4.0       3.50         5550
# 252   2014-05-07 00:00:00   3200000.0       7.0       4.50         6210
# 1567  2014-05-29 00:00:00   3100000.0       6.0       4.25         6980
# 2772  2014-06-18 00:00:00   3000000.0       4.0       4.25         4850
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4350      7793     1.0           0     0          4        1180
# ...
